# %% [markdown]
# ## Quiz

# %%
from bs4 import BeautifulSoup
import os
import pandas as pd

# %%
df_list = []
folder = 'rt_html'
for movie_html in os.listdir(folder):
    with open(os.path.join(folder, movie_html)) as file:
        # Your code here
        # Note: a correct implementation may take ~15 seconds to run
        soup = BeautifulSoup(file, 'lxml')
        title = soup.find('title').contents[0][:-len(' - Rotten Tomatoes')]
        print(title)
        break
# Out:
# The Grapes of Wrath (1940)

# %%
df_list = []
folder = 'rt_html'
for movie_html in os.listdir(folder):
    with open(os.path.join(folder, movie_html)) as file:
        # Your code here
        # Note: a correct implementation may take ~15 seconds to run
        soup = BeautifulSoup(file, 'lxml')
        title = soup.find('title').contents[0][:-len(' - Rotten Tomatoes')]
        audience_score = soup.find('div', class_ = 'audience-score meter').find('span').contents[0]
        print(audience_score)
        break
# Out:
# 88%

# %%
df_list = []
folder = 'rt_html'
for movie_html in os.listdir(folder):
    with open(os.path.join(folder, movie_html)) as file:
        # Your code here
        # Note: a correct implementation may take ~15 seconds to run
        soup = BeautifulSoup(file, 'lxml')
        title = soup.find('title').contents[0][:-len(' - Rotten Tomatoes')]
        audience_score = soup.find('div', class_ = 'audience-score meter').find('span').contents[0][:-1]
        print(audience_score)
        break
# Out:
# 88

# %%
df_list = []
folder = 'rt_html'
for movie_html in os.listdir(folder):
    with open(os.path.join(folder, movie_html)) as file:
        # Your code here
        # Note: a correct implementation may take ~15 seconds to run
        soup = BeautifulSoup(file, 'lxml')
        title = soup.find('title').contents[0][:-len(' - Rotten Tomatoes')]
        audience_score = soup.find('div', class_ = 'audience-score meter').find('span').contents[0][:-1]
        num_audience_ratings = soup.find('div', class_ = 'audience-info hidden-xs superPageFontColor')
        print(num_audience_ratings)
        break
# Out:
# <div class="audience-info hidden-xs superPageFontColor">
# <div>
# <span class="subtle superPageFontColor">Average Rating:</span>
#             3.9/5
#                 </div>
# <div>
# <span class="subtle superPageFontColor">User Ratings:</span>
#         23,954</div>
# </div>

# %%
df_list = []
folder = 'rt_html'
for movie_html in os.listdir(folder):
    with open(os.path.join(folder, movie_html)) as file:
        # Your code here
        # Note: a correct implementation may take ~15 seconds to run
        soup = BeautifulSoup(file, 'lxml')
        title = soup.find('title').contents[0][:-len(' - Rotten Tomatoes')]
        audience_score = soup.find('div', class_ = 'audience-score meter').find('span').contents[0][:-1]
        num_audience_ratings = soup.find('div', class_ = 'audience-info')
        print(num_audience_ratings)
        break
# Out:
# <div class="audience-info hidden-xs superPageFontColor">
# <div>
# <span class="subtle superPageFontColor">Average Rating:</span>
#             3.9/5
#                 </div>
# <div>
# <span class="subtle superPageFontColor">User Ratings:</span>
#         23,954</div>
# </div>

# %%
df_list = []
folder = 'rt_html'
for movie_html in os.listdir(folder):
    with open(os.path.join(folder, movie_html)) as file:
        # Your code here
        # Note: a correct implementation may take ~15 seconds to run
        soup = BeautifulSoup(file, 'lxml')
        title = soup.find('title').contents[0][:-len(' - Rotten Tomatoes')]
        audience_score = soup.find('div', class_ = 'audience-score meter').find('span').contents[0][:-1]
        num_audience_ratings = soup.find('div', class_ = 'audience-info hidden-xs superPageFontColor')
        num_audience_ratings = num_audience_ratings.find_all('div')[1].contents[2].strip().replace(',','')
        print(num_audience_ratings)
        break
# Out:
# 23954

# %%
df_list = []
folder = 'rt_html'
for movie_html in os.listdir(folder):
    with open(os.path.join(folder, movie_html)) as file:
        # Your code here
        # Note: a correct implementation may take ~15 seconds to run
        soup = BeautifulSoup(file, 'lxml')
        title = soup.find('title').contents[0][:-len(' - Rotten Tomatoes')]
        audience_score = soup.find('div', class_ = 'audience-score meter').find('span').contents[0][:-1]
        num_audience_ratings = soup.find('div', class_ = 'audience-info hidden-xs superPageFontColor')
        num_audience_ratings = num_audience_ratings.find_all('div')[1].contents[2].strip().replace(',','')
        df_list.append({'title': title,
                        'audience_score': int(audience_score),
                        'number_of_audience_ratings': int(num_audience_ratings)})

# %%
df = pd.DataFrame(df_list, columns = ['title', 'audience_score', 'number_of_audience_ratings'])
df
# Out:
#                                                 title  audience_score  \
# 0                          The Grapes of Wrath (1940)              88
# 1                                Touch of Evil (1958)              92
# 2                                Roman Holiday (1953)              94
# 3   Dr. Strangelove Or How I Learned to Stop Worry...              94
# 4                   E.T. The Extra-Terrestrial (1982)              72
# 5                                   Inside Out (2015)              89
# 6                                    Repulsion (1965)              87
# 7                                   La La Land (2016)              82
# 8                              The Dark Knight (2008)              94
# 9                           Gone With the Wind (1939)              93
# 10                                 Taxi Driver (1976)              93
# 11                                  Metropolis (1927)              92
# 12             Snow White and the Seven Dwarfs (1937)              78
# 13                             Rosemary's Baby (1968)              87
# 14                                          Up (2009)              90
# 15                          Hell or High Water (2016)              88
# 16                               All About Eve (1950)              94
# 17                       It Happened One Night (1934)              93
# 18                         Battleship Potemkin (1925)              85
# 19            The Treasure of the Sierra Madre (1948)              93
# 20      The 400 Blows (Les Quatre cents coups) (1959)              94
# 21                                  Casablanca (1942)              95
# 22             12 Angry Men (Twelve Angry Men) (1957)              97
# 23                         Singin' in the Rain (1952)              95
# 24                            The Wizard of Oz (1939)              89
# 25                                        Argo (2012)              90
# 26  The Cabinet of Dr. Caligari (Das Cabinet des D...              89
# 27                          North by Northwest (1959)              94
# 28                                   Toy Story (1995)              92
# 29                               The Godfather (1972)              98
# ..                                                ...             ...
# 70                                The Wrestler (2008)              88
# 71                           L.A. Confidential (1997)              94
# 72                           On the Waterfront (1954)              95
# 73                    A Streetcar Named Desire (1951)              90
# 74                                   Star Trek (2009)              91
# 75                              Apocalypse Now (1979)              94
# 76  Nosferatu, a Symphony of Horror (Nosferatu, ei...              87
# 77                                Frankenstein (1931)              87
# 78                                     Rebecca (1940)              92
# 79              The Good, the Bad and the Ugly (1966)              97
# 80                                The 39 Steps (1935)              86
# 81                          A Hard Day's Night (1964)              89
# 82                                   Moonlight (2016)              80
# 83                                Modern Times (1936)              95
# 84         La Grande illusion (Grand Illusion) (1938)              92
# 85                                 Baby Driver (2017)              89
# 86                              The Conformist (1970)              91
# 87                                   High Noon (1952)              89
# 88                                    Zootopia (2016)              92
# 89                               The Third Man (1949)              93
# 90        Seven Samurai (Shichinin no Samurai) (1956)              97
# 91                            12 Years a Slave (2013)              90
# 92                       Manchester by the Sea (2016)              77
# 93                                     Boyhood (2014)              81
# 94                                Wonder Woman (2017)              90
# 95  The Battle of Algiers (La Battaglia di Algeri)...              95
# 96                      The Godfather, Part II (1974)              97
# 97                                   Spotlight (2015)              93
# 98                                       Laura (1944)              91
# 99                                    Rashômon (1951)              93
#
#     number_of_audience_ratings
# 0                        23954
# 1                        30867
# 2                        62895
# 3                       208215
# 4                     32313030
# 5                       133558
# 6                        18655
# 7                        67325
# 8                      1827436
# 9                       292794
# 10                      258405
# 11                       62018
# 12                      469510
# 13                       72669
# 14                     1201878
# 15                       37738
# 16                       44564
# 17                       33106
# 18                       18709
# 19                       25627
# 20                       38368
# 21                      355952
# 22                      103672
# 23                      137643
# 24                      874425
# 25                      207373
# 26                       27163
# 27                       78793
# 28                     1107731
# 29                      730433
# ..                         ...
# 70                      139795
# 71                      149772
# 72                       51664
# 73                       54761
# 74                      746458
# 75                      284606
# 76                       47463
# 77                       41140
# 78                       39026
# 79                      238420
# 80                       23647
# 81                       50067
# 82                       41956
# 83                       39736
# 84                       11490
# 85                       48114
# 86                        8529
# 87                       25065
# 88                       98633
# 89                       53081
# 90                       90049
# 91                      138789
# 92                       48189
# 93                       88478
# 94                      112955
# 95                       14267
# 96                      409574
# 97                       68142
# 98                       10481
# 99                       47657
#
# [100 rows x 3 columns]

# %%
df_list = []
folder = 'rt_html'
for movie_html in os.listdir(folder): 
    with open(os.path.join(folder, movie_html)) as file:
        
    # Your code here 
        soup = BeautifulSoup(file, 'lxml') 
        title = soup.find('title').contents[0][:-len(' - Rotten Tomatoes')] 
        audience_score = soup.find('div', class_ = 'audience-score meter').find('span').contents[0][:-1]
        num_audience_ratings = soup.find('div', class_='audience-info hidden-xs superPageFontColor')
        num_audience_ratings = num_audience_ratings.find_all('div')[1].contents[2].strip().replace(',', '') 
        df_list.append({'title': title, 
                        'audience_score': int(audience_score), 
                        'number_of_audience_ratings': int(num_audience_ratings)})

# %%
df = pd.DataFrame(df_list, columns = ['title', 'audience_score', 'number_of_audience_ratings'])

# %%
df
# Out:
#                                                 title  audience_score  \
# 0                          The Grapes of Wrath (1940)              88
# 1                                Touch of Evil (1958)              92
# 2                                Roman Holiday (1953)              94
# 3   Dr. Strangelove Or How I Learned to Stop Worry...              94
# 4                   E.T. The Extra-Terrestrial (1982)              72
# 5                                   Inside Out (2015)              89
# 6                                    Repulsion (1965)              87
# 7                                   La La Land (2016)              82
# 8                              The Dark Knight (2008)              94
# 9                           Gone With the Wind (1939)              93
# 10                                 Taxi Driver (1976)              93
# 11                                  Metropolis (1927)              92
# 12             Snow White and the Seven Dwarfs (1937)              78
# 13                             Rosemary's Baby (1968)              87
# 14                                          Up (2009)              90
# 15                          Hell or High Water (2016)              88
# 16                               All About Eve (1950)              94
# 17                       It Happened One Night (1934)              93
# 18                         Battleship Potemkin (1925)              85
# 19            The Treasure of the Sierra Madre (1948)              93
# 20      The 400 Blows (Les Quatre cents coups) (1959)              94
# 21                                  Casablanca (1942)              95
# 22             12 Angry Men (Twelve Angry Men) (1957)              97
# 23                         Singin' in the Rain (1952)              95
# 24                            The Wizard of Oz (1939)              89
# 25                                        Argo (2012)              90
# 26  The Cabinet of Dr. Caligari (Das Cabinet des D...              89
# 27                          North by Northwest (1959)              94
# 28                                   Toy Story (1995)              92
# 29                               The Godfather (1972)              98
# ..                                                ...             ...
# 70                                The Wrestler (2008)              88
# 71                           L.A. Confidential (1997)              94
# 72                           On the Waterfront (1954)              95
# 73                    A Streetcar Named Desire (1951)              90
# 74                                   Star Trek (2009)              91
# 75                              Apocalypse Now (1979)              94
# 76  Nosferatu, a Symphony of Horror (Nosferatu, ei...              87
# 77                                Frankenstein (1931)              87
# 78                                     Rebecca (1940)              92
# 79              The Good, the Bad and the Ugly (1966)              97
# 80                                The 39 Steps (1935)              86
# 81                          A Hard Day's Night (1964)              89
# 82                                   Moonlight (2016)              80
# 83                                Modern Times (1936)              95
# 84         La Grande illusion (Grand Illusion) (1938)              92
# 85                                 Baby Driver (2017)              89
# 86                              The Conformist (1970)              91
# 87                                   High Noon (1952)              89
# 88                                    Zootopia (2016)              92
# 89                               The Third Man (1949)              93
# 90        Seven Samurai (Shichinin no Samurai) (1956)              97
# 91                            12 Years a Slave (2013)              90
# 92                       Manchester by the Sea (2016)              77
# 93                                     Boyhood (2014)              81
# 94                                Wonder Woman (2017)              90
# 95  The Battle of Algiers (La Battaglia di Algeri)...              95
# 96                      The Godfather, Part II (1974)              97
# 97                                   Spotlight (2015)              93
# 98                                       Laura (1944)              91
# 99                                    Rashômon (1951)              93
#
#     number_of_audience_ratings
# 0                        23954
# 1                        30867
# 2                        62895
# 3                       208215
# 4                     32313030
# 5                       133558
# 6                        18655
# 7                        67325
# 8                      1827436
# 9                       292794
# 10                      258405
# 11                       62018
# 12                      469510
# 13                       72669
# 14                     1201878
# 15                       37738
# 16                       44564
# 17                       33106
# 18                       18709
# 19                       25627
# 20                       38368
# 21                      355952
# 22                      103672
# 23                      137643
# 24                      874425
# 25                      207373
# 26                       27163
# 27                       78793
# 28                     1107731
# 29                      730433
# ..                         ...
# 70                      139795
# 71                      149772
# 72                       51664
# 73                       54761
# 74                      746458
# 75                      284606
# 76                       47463
# 77                       41140
# 78                       39026
# 79                      238420
# 80                       23647
# 81                       50067
# 82                       41956
# 83                       39736
# 84                       11490
# 85                       48114
# 86                        8529
# 87                       25065
# 88                       98633
# 89                       53081
# 90                       90049
# 91                      138789
# 92                       48189
# 93                       88478
# 94                      112955
# 95                       14267
# 96                      409574
# 97                       68142
# 98                       10481
# 99                       47657
#
# [100 rows x 3 columns]

# %% [markdown]
# ## Solution Test
# Run the cell below the see if your solution is correct. If an `AssertionError` is thrown, your solution is incorrect. If no error is thrown, your solution is correct.

# %%
df_solution = pd.read_pickle('df_solution.pkl')
df.sort_values('title', inplace = True)
df.reset_index(inplace = True, drop = True)
df_solution.sort_values('title', inplace = True)
df_solution.reset_index(inplace = True, drop = True)
pd.testing.assert_frame_equal(df, df_solution)
